# %% [markdown]
# ## Solar Power Prediction Using Linear Regration

# %%
# import necessary libraries
import pandas as pd # Pandas provides DataFrame and Series objects that allow structured data manipulation
import numpy as np # Numpy is optimized for numerical computations like mathematical operations
import seaborn as sns # Import seaborn library for creating aesthetic visualizations

# %%
# Load the dataset
df = pd.read_csv('C:/Users/ag502/OneDrive/Desktop/solor power pridiction/dataset/solarpowergeneration.csv')

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
# To check Bottom or last Five Rows
df.tail() #df stnads for 'DATA FRAME'
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 4208                       8.69                               66
# 4209                       7.57                               90
# 4210                       7.27                               90
# 4211                       8.25                               81
# 4212                       8.00                               80
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 4208                       1025.1                      0.0
# 4209                       1026.1                      0.0
# 4210                       1026.3                      0.1
# 4211                       1025.5                      0.0
# 4212                       1025.3                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 4208                  0.0                  100.0
# 4209                  0.0                  100.0
# 4210                  0.0                  100.0
# ...

# %%
# if we want top ten ROWS
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
# To check the total numer of rows and columns
df.shape
# Out:
# (4213, 21)

# %%
# Display summary
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
# check the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
# check for the missing values
df.isnull().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
# check dublicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# columns name
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd',
#        'wind_speed_900_mb', 'wind_direction_900_mb',
#        'wind_gust_10_m_above_gnd', 'angle_of_incidence', 'zenith', 'azimuth',
#        'generated_power_kw'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
# plot distribution of power
plt.figure(figsize=(10, 6))
sns.histplot(df['generated_power_kw'], bins=30, kde=True)
plt.title('Distribution of Generated power (KW)')
plt.xlabel('Generated power (KW)')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot: Histogram with custom bin size
plt.figure(figsize=(10, 6))
sns.histplot(df['generated_power_kw'], bins=50, kde=True, color='purple')
plt.title('Histogram of Generated Power with KDE')
plt.xlabel('Generated Power (kW)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### EDA

# %% [markdown]
# # Histograms for remaining column

# %%
df[df.columns[:9]].hist(bins=30, figsize=(15, 10))
plt.show()

# %%
# I improve labels and grid lines and distinct colors for each and organized in drid layout
# Set figure size
fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # 3x3 grid for 9 features
axes = axes.flatten()  # Flatten for easy indexing

# Define color palette for better distinction
colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink', 'cyan', 'brown', 'gray']

# Loop through the first 9 columns to create histograms
for i, col in enumerate(df.columns[:9]):
    df[col].hist(ax=axes[i], bins=25, color=colors[i], edgecolor='black', alpha=0.7)
    axes[i].set_title(f'Distribution of {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(col, fontsize=10)
    axes[i].set_ylabel('Frequency', fontsize=10)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7)  # Adding grid for better readability

# Adjust layout to prevent overlap
plt.tight_layout()
plt.suptitle('Feature Distributions', fontsize=16, fontweight='bold', y=1.02)  # Title for entire plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['generated_power_kw'], color='orange')
plt.title('Scatter Plot of Generated Power (kW)')
plt.xlabel('Index')
plt.ylabel('Generated Power (kW)')
plt.grid(True)
plt.show()

# %%
# Filter only numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

# Remove target column if it exists
if 'generated_power_kw' in numeric_columns:
    numeric_columns.remove('generated_power_kw')

# Check if there are numeric columns left
if not numeric_columns:
    print("No numeric columns available for plotting.")
else:
    # Dynamically adjust subplot grid
    rows = (len(numeric_columns) // 3) + 1  # Calculate required rows

    plt.figure(figsize=(15, 5 * rows))  # Adjust figure size based on rows

    for i, column in enumerate(numeric_columns, start=1):  # Start index from 1
        plt.subplot(rows, 3, i)
        plt.scatter(df[column], df['generated_power_kw'], alpha=0.5, c='blue')
        plt.title(f'{column} vs Generated Power (kW)')
        plt.xlabel(column)
        plt.ylabel('Generated Power (kW)')

    plt.tight_layout()
    plt.show()

# %%
df.corr()
# Out:
#                                    temperature_2_m_above_gnd  \
# temperature_2_m_above_gnd                           1.000000
# relative_humidity_2_m_above_gnd                    -0.771704
# mean_sea_level_pressure_MSL                        -0.402240
# total_precipitation_sfc                            -0.083137
# snowfall_amount_sfc                                -0.121422
# total_cloud_cover_sfc                              -0.326641
# high_cloud_cover_high_cld_lay                      -0.019522
# medium_cloud_cover_mid_cld_lay                     -0.100980
# low_cloud_cover_low_cld_lay                        -0.381876
# shortwave_radiation_backwards_sfc                   0.665755
# wind_speed_10_m_above_gnd                          -0.172532
# wind_direction_10_m_above_gnd                       0.051393
# wind_speed_80_m_above_gnd                          -0.244869
# wind_direction_80_m_above_gnd                       0.086630
# ...

# %%
# Outlier
plt.figure(figsize=(15, 30))
for i, column in enumerate(df.columns):
    plt.subplot(7, 3, i+1)
    sns.boxplot(df[column])
    plt.show()

# %%
# Filters only numeric columns using df.select_dtypes(include=['number'])
# Better color representation using color='skyblue'
# Prevents clutter by using plt.tight_layout()
# Ensures proper spacing by using rotation=45

# Set style for better readability
sns.set_style('whitegrid')

# Create a figure for all boxplots
plt.figure(figsize=(15, 30))

# Loop through numerical columns and plot boxplots
for i, column in enumerate(df.select_dtypes(include=['number']).columns, 1):
    plt.subplot(7, 3, i)
    sns.boxplot(x=df[column], color='skyblue')
    plt.title(f'Boxplot of {column}')
    plt.xticks(rotation=45)

# Adjust layout and display plots
plt.tight_layout()
plt.show()
